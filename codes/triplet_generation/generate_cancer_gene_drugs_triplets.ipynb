# %%
import pandas as pd

# %%
# Read data from the first file into a DataFrame
df1 = pd.read_csv("patient_mutationgene_triplet.txt", sep="\t", header=0, names=["patient_id", "mutation", "gene"])

# %%
df1
# Out:
#            patient_id             mutation      gene
# 0        TCGA-OR-A5J1       intron_variant    GOLGA3
# 1        TCGA-OR-A5J1     missense_variant     KLRB1
# 2        TCGA-OR-A5J1     missense_variant     SALL2
# 3        TCGA-OR-A5J1   synonymous_variant     PLCB2
# 4        TCGA-OR-A5J1   frameshift_variant  C15orf27
# ...               ...                  ...       ...
# 3529412  TCGA-YZ-A985  3_prime_UTR_variant     RUNX2
# 3529413  TCGA-YZ-A985  3_prime_UTR_variant    CARD11
# 3529414  TCGA-YZ-A985  3_prime_UTR_variant     CDH17
# 3529415  TCGA-YZ-A985  3_prime_UTR_variant      XKRX
# 3529416  TCGA-YZ-A985  3_prime_UTR_variant     PDZD4
#
# [3529417 rows x 3 columns]

# %%
# Read data from the second file into another DataFrame
df2 = pd.read_csv("patient_cancer_status_triplet.txt", sep="\t", header=0, names=["patient_id", "has_cancer", "cancer type"])

# %%
df2
# Out:
#          patient_id  has_cancer               cancer type
# 0      TCGA-OR-A5J2  has cancer  Adrenocortical carcinoma
# 1      TCGA-OR-A5J3  has cancer  Adrenocortical carcinoma
# 2      TCGA-OR-A5J4  has cancer  Adrenocortical carcinoma
# 3      TCGA-OR-A5J5  has cancer  Adrenocortical carcinoma
# 4      TCGA-OR-A5J6  has cancer  Adrenocortical carcinoma
# ...             ...         ...                       ...
# 10947  TCGA-V4-A9F3  has cancer            Uveal Melanoma
# 10948  TCGA-V4-A9EY  has cancer            Uveal Melanoma
# 10949  TCGA-V4-A9E5  has cancer            Uveal Melanoma
# 10950  TCGA-WC-A883  has cancer            Uveal Melanoma
# 10951  TCGA-VD-AA8P  has cancer            Uveal Melanoma
#
# [10952 rows x 3 columns]

# %%
cancer_gene = pd.merge(df2, df1, on="patient_id", how="left")

# %%
cancer_gene
# Out:
#            patient_id  has_cancer               cancer type  \
# 0        TCGA-OR-A5J2  has cancer  Adrenocortical carcinoma
# 1        TCGA-OR-A5J2  has cancer  Adrenocortical carcinoma
# 2        TCGA-OR-A5J2  has cancer  Adrenocortical carcinoma
# 3        TCGA-OR-A5J2  has cancer  Adrenocortical carcinoma
# 4        TCGA-OR-A5J2  has cancer  Adrenocortical carcinoma
# ...               ...         ...                       ...
# 3530219  TCGA-VD-AA8P  has cancer            Uveal Melanoma
# 3530220  TCGA-VD-AA8P  has cancer            Uveal Melanoma
# 3530221  TCGA-VD-AA8P  has cancer            Uveal Melanoma
# 3530222  TCGA-VD-AA8P  has cancer            Uveal Melanoma
# 3530223  TCGA-VD-AA8P  has cancer            Uveal Melanoma
#
#                         mutation         gene
# 0               missense_variant        GFRA1
# 1               missense_variant         LRP6
# 2               missense_variant        KIF5A
# 3             frameshift_variant        BBS10
# 4                    stop_gained        SUGT1
# ...                          ...          ...
# 3530219         missense_variant        TMEM2
# 3530220              stop_gained       TMEM35
# 3530221         missense_variant       RAB33A
# 3530222         missense_variant      DCAF8L2
# 3530223  downstream_gene_variant  CTC-260E6.2
#
# [3530224 rows x 5 columns]

# %%
cancer_gene = cancer_gene.drop(columns=['patient_id','has_cancer'])

# %%
cancer_gene
# Out:
#                       cancer type                 mutation         gene
# 0        Adrenocortical carcinoma         missense_variant        GFRA1
# 1        Adrenocortical carcinoma         missense_variant         LRP6
# 2        Adrenocortical carcinoma         missense_variant        KIF5A
# 3        Adrenocortical carcinoma       frameshift_variant        BBS10
# 4        Adrenocortical carcinoma              stop_gained        SUGT1
# ...                           ...                      ...          ...
# 3530219            Uveal Melanoma         missense_variant        TMEM2
# 3530220            Uveal Melanoma              stop_gained       TMEM35
# 3530221            Uveal Melanoma         missense_variant       RAB33A
# 3530222            Uveal Melanoma         missense_variant      DCAF8L2
# 3530223            Uveal Melanoma  downstream_gene_variant  CTC-260E6.2
#
# [3530224 rows x 3 columns]

# %%
df3 = pd.read_csv("patient_treatment.txt", sep="\t", header=0, names=["patient_id", "treatment"])

# %%
df3
# Out:
#          patient_id                                          treatment
# 0      TCGA-OR-A5JF  The patient was treated with Radiation Therapy...
# 1      TCGA-OR-A5JK  The patient was treated with Radiation Therapy...
# 2      TCGA-OR-A5JM  The patient was treated with Targeted Molecula...
# 3      TCGA-OR-A5JM  The patient was treated with Targeted Molecula...
# 4      TCGA-OR-A5JM  The patient was treated with Radiation Therapy...
# ...             ...                                                ...
# 15475  TCGA-V4-A9ET  The patient was treated with Chemotherapy usin...
# 15476  TCGA-V4-A9F1  The patient was treated with Chemotherapy usin...
# 15477  TCGA-V4-A9F3  The patient was treated with Chemotherapy usin...
# 15478  TCGA-WC-A87Y  The patient was treated with Radiation Therapy...
# 15479  TCGA-WC-AA9E  The patient was treated with Radiation Therapy...
#
# [15480 rows x 2 columns]

# %%
df3['treatment'] = df3['treatment'].str.replace('The patient was treated with', '')

# %%
df3
# Out:
#          patient_id                                          treatment
# 0      TCGA-OR-A5JF   Radiation Therapy using agent Radiation 1 wit...
# 1      TCGA-OR-A5JK   Radiation Therapy using agent Radiation 1 wit...
# 2      TCGA-OR-A5JM   Targeted Molecular Therapy using agent Suniti...
# 3      TCGA-OR-A5JM   Targeted Molecular Therapy using agent Ketoco...
# 4      TCGA-OR-A5JM   Radiation Therapy using agent Radiation 1 wit...
# ...             ...                                                ...
# 15475  TCGA-V4-A9ET   Chemotherapy using agent Fotemustine with res...
# 15476  TCGA-V4-A9F1   Chemotherapy using agent Fotemustine with res...
# 15477  TCGA-V4-A9F3   Chemotherapy using agent Fotemustine with res...
# 15478  TCGA-WC-A87Y   Radiation Therapy using agent Radiation 1 wit...
# 15479  TCGA-WC-AA9E   Radiation Therapy using agent Radiation 1 wit...
#
# [15480 rows x 2 columns]

# %%
delimiter = 'using agent'

# %%
df3['drugs'] = df3['treatment'].str.split(delimiter, expand=True)[1]

# %%
df3
# Out:
#          patient_id                                          treatment  \
# 0      TCGA-OR-A5JF   Radiation Therapy using agent Radiation 1 wit...
# 1      TCGA-OR-A5JK   Radiation Therapy using agent Radiation 1 wit...
# 2      TCGA-OR-A5JM   Targeted Molecular Therapy using agent Suniti...
# 3      TCGA-OR-A5JM   Targeted Molecular Therapy using agent Ketoco...
# 4      TCGA-OR-A5JM   Radiation Therapy using agent Radiation 1 wit...
# ...             ...                                                ...
# 15475  TCGA-V4-A9ET   Chemotherapy using agent Fotemustine with res...
# 15476  TCGA-V4-A9F1   Chemotherapy using agent Fotemustine with res...
# 15477  TCGA-V4-A9F3   Chemotherapy using agent Fotemustine with res...
# 15478  TCGA-WC-A87Y   Radiation Therapy using agent Radiation 1 wit...
# 15479  TCGA-WC-AA9E   Radiation Therapy using agent Radiation 1 wit...
#
#                                                    drugs
# 0       Radiation 1 with response measure.complete re...
# 1       Radiation 1 with response measure.stable dise...
# 2       Sunitinib with response measure clinical prog...
# 3       Ketoconazole with response measure clinical p...
# 4       Radiation 1 with response measure.radiographi...
# ...                                                  ...
# 15475                Fotemustine with response measure .
# 15476                Fotemustine with response measure .
# 15477                Fotemustine with response measure .
# 15478   Radiation 1 with response measure.stable dise...
# 15479   Radiation 1 with response measure.complete re...
#
# [15480 rows x 3 columns]

# %%
delimiter2='with response measure'

# %%
df3['drugs'] = df3['drugs'].str.replace('with response measure.*', '', regex=True)

# %%
df3['treatment'] = df3['treatment'].str.replace('using agent.*', '', regex=True)

# %%
df3
# Out:
#          patient_id                     treatment           drugs
# 0      TCGA-OR-A5JF            Radiation Therapy     Radiation 1
# 1      TCGA-OR-A5JK            Radiation Therapy     Radiation 1
# 2      TCGA-OR-A5JM   Targeted Molecular Therapy       Sunitinib
# 3      TCGA-OR-A5JM   Targeted Molecular Therapy    Ketoconazole
# 4      TCGA-OR-A5JM            Radiation Therapy     Radiation 1
# ...             ...                           ...             ...
# 15475  TCGA-V4-A9ET                 Chemotherapy     Fotemustine
# 15476  TCGA-V4-A9F1                 Chemotherapy     Fotemustine
# 15477  TCGA-V4-A9F3                 Chemotherapy     Fotemustine
# 15478  TCGA-WC-A87Y            Radiation Therapy     Radiation 1
# 15479  TCGA-WC-AA9E            Radiation Therapy     Radiation 1
#
# [15480 rows x 3 columns]

# %%
treatment = df3['treatment'].unique()
print(treatment)
# Out:
# [' Radiation Therapy ' ' Targeted Molecular Therapy ' ' Chemotherapy '
#  ' Immunotherapy ' ' Not Specified ' ' Ancillary ' ' Other '
#  ' Hormone Therapy ' ' Vaccine ']

# %%
drugs = df3['drugs'].unique()
print(drugs)
# Out:
# [' Radiation 1 ' ' Sunitinib ' ' Ketoconazole ' ' Radiation 2 '
#  ' Capecitabine ' ' Doxorubicin ' ' Cisplatin ' ' Carboplatin '
#  ' Etoposide ' ' Bevacizumab ' ' Mitotane ' ' Streptozocin ' ' Sorafenib '
#  ' Radiation 10 ' ' Radiation 3 ' ' Radiation 4 ' ' Radiation 5 '
#  ' Radiation 6 ' ' Radiation 7 ' ' Radiation 8 ' ' Radiation 9 '
#  ' Bacillus Calmette-Guerin ' ' Gemcitabine ' ' Docetaxel '
#  ' Oxaliplatin ' ' Paclitaxel ' ' Fluorouracil ' '  ' ' Ifosfamide '
#  ' Ipilimumab ' ' Nivolumab ' ' Vinblastine ' ' Methotrexate '
#  ' Sodium Mercaptoetansolfonato ' ' Erlotinib ' ' Fosaprepitant '
#  ' Halichondrin B ' ' Vorinostat ' ' Platinum ' ' Temozolomide '
#  ' Vincristine ' ' Docetaxel + Vandetanib ' ' Gemcitabine + Cisplatin '
#  ' Goserelin ' ' Poly E ' ' Metformin ' ' Trastuzumab '
#  ' Cyclophosphamide ' ' Tamoxifen ' ' Letrozole '
#  ' Cyclophosphamide + Docetaxel ' ' Anastrazole '
#  ' Doxorubicin + Cyclophosphamide ' ' Zoledronic Acid ' ' AE37 '
#  ' Exemestane ' ' Nelipepimut-S ' ' Fulvestrant ' ' Denosumab '
#  ' Leuprolide ' ' Lapatinib ' ' Vinorelbine ' ' Epirubicin '
#  ' Ibandronate ' ' Pamidronic Acid ' ' Chemo, NOS ' ' Hormone, NOS '
#  ' Palonosetron ' ' Tesetaxel ' ' Rituximab ' ' Prednisone '
#  ' Triptorelin ' ' Doxorubicin + Cyclophosphamide + Tamoxifen '
#  ' Tamoxifen + Leuprolide + Goserelin ' ' Tamoxifen + Anastrozole '
#  ' Cyclophosphamide + Methotrexate + Fluorouracil '
#  ' Paclitaxel + Doxorubicin + Cyclophosphamide + Trastuzumab '
#  ' Everolimus ' ' Clodronic Acid ' ' Pemetrexed ' ' Toremifene '
#  ' Doxorubicin + Cytoxan + Avastin ' ' Mitomycin ' ' Mitoxantrone '
#  ' Docetaxel + Carboplatin + Trastuzumab ' ' Megestrol Acetate '
#  ' Trabectedin ' ' Ixabepilone ' ' Pegfilgrastim ' ' Bleomycin '
#  ' Hydrocortisone ' ' Amifostine ' ' Cetuximab ' ' Topotecan '
#  ' Cisplatin + Xrt ' ' Conatumumab ' ' Irinotecan ' ' Leucovorin '
#  ' Panitumumab ' ' Leucovorin + Fluorouracil + Oxaliplatin '
#  ' Floxuridine ' ' Aflibercept '
#  ' Leucovorin + Fluorouracil + Irinotecan ' ' Filgrastim '
#  ' Dexamethasone '
#  ' Leucovorin + Oxaliplatin + Fluorouracil + Dexamethasone '
#  ' Oxaliplatin + Fluorouracil ' ' Fluorouracil + Leucovorin ' ' Nos '
#  ' Irinotecan + Fluorouracil ' ' Raltitrexed ' ' Regorafenib '
#  ' Leucovorin + Fluorouracil + Irinotecan + Aflibercept '
#  ' Irinotecan + Cetuximab '
#  ' Leucovorin + Fluorouracil + Irinotecan + Bevacizumab ' ' Prednisolone '
#  ' Dacarbazine ' ' Etoposide + Prednisone + Vincristine + Doxorubicin '
#  ' Cyclophosphamide + Doxorubicin + Vincristine + Prednisone '
#  ' Ifosfamide + Carboplatin + Etoposide '
#  ' Cyclophosphamide + Vincristine + Doxorubicin + Dexamethasone '
#  ' Ofatumumab ' ' Lenalidomide ' ' Cytarabine ' ' Bortezomib '
#  ' Human\xa0Interleukin-2 ' ' Thiotepa ' ' Methylprednisolone '
#  ' Methotrexate + Leucovorin ' ' Isotretinoin ' ' Celecoxib '
#  ' Antineoplastons ' ' Carmustine ' ' Lomustine ' ' Procarbazine '
#  ' Tetrathiomolybdate ' ' Suramin ' ' Irofulven '
#  ' Interleukin-13 + Pseudomonas Exotoxin ' ' Cai Nabit 9712 '
#  ' Pyrazinamide ' ' Ci-980 ' ' Imatinib ' ' Tipifarnib '
#  ' Arsenic Trioxide ' ' Cabozantinib ' ' Cediranib ' ' 6-O-Benzylguanine '
#  ' Vatalanib ' " 13-Cis-12-(3'-Carboxyphenyl)Retinoic\xa0Acid "
#  ' Cilengitide ' ' Estramustine ' ' Tioguanine ' ' Hydroxyurea '
#  ' 9-Aminocamptothecin ' ' Azd ' ' Gossypol '
#  ' 5,8-Di-Amino-1,4-Dihydroxy-Anthraquinone '
#  ' Dc Vax (Dendritic Cell Vaccine) ' ' Veliparib ' ' R04929097 '
#  ' Iniparib ' ' Hydroxychloroquine ' ' Vandetanib ' ' Pexidartinib '
#  ' Fenretinide ' ' Poly-Iclc ' ' Enzastaurin ' ' Sirolimus '
#  ' Interferon Alfa ' ' Hsppc-96 Vaccine ' ' Sch-63666 ' ' Mab I-131 '
#  ' 81C6 ' ' Ch81C6 ' ' Ridaforolimus ' ' Lonafarnib ' ' O6-Benzylguanine '
#  ' Attac ' ' 2-Methoxyestradiol ' ' Dactinomycin ' ' Rilotumumab '
#  ' Chloroquine ' ' Pep-3-Klh ' ' Daclizumab ' ' Pegdinetanib '
#  ' Carboxyamidotriazole ' ' Vismodegib ' ' Motexafin Gadolinium '
#  ' Oxcarbazepine ' ' Fotemustine ' ' Fluorouracil + Tegafur '
#  ' Levetiracetam ' ' Potassium Chloride ' ' Polychlorinated Biphenyl '
#  ' Valproic Acid ' ' Phenytoin ' ' Tumor Vaccine Nos ' ' Afatinib '
#  ' Ict-107 ' ' Vaccine Nos ' ' Cixutumumab ' ' Gefitinib ' ' Rigosertib '
#  ' Eribulin ' ' Sonolisib ' ' Perifosine ' ' Interferon Nos '
#  ' Pazopanib ' ' Tki Nos ' ' Infliximab ' ' Temsirolimus ' ' Axitinib '
#  ' Vitespen ' ' Alvespimycin ' ' Psma Dna Vaccine ' ' Cdr0000654697 '
#  ' Procarbazine + Lomustine + Vincristine ' ' Broxuridine ' ' Mibefradil '
#  ' Leflunomide ' ' Onyx-015 ' ' Cositecan ' ' Laromustine ' ' Cbp501 '
#  ' Teniposide ' ' Pembrolizumab ' ' Nimustine ' ' Pasireotide '
#  ' Veliparib + Temozolomide ' ' Everolimus + Gemcitabine + Cisplatin '
#  ' Ly228820 ' ' Alvesin ' ' Sorafenib Vs Sorafenib + Doxorubicin '
#  ' Recprame + As15/Placebo ' ' Recprame + As15 ' ' Placebo '
#  ' Cyclophosphamide + Cyc116 ' ' Belinostat ' ' Cyanocobalamin '
#  ' Ras Inhibitor Nos ' ' Cyclophosphamide + Dactinomycin + Vincristine '
#  ' Clinical Trial ' ' Recmage-A + As15/Placebo '
#  ' Carboplatin + Paclitaxel ' ' Cisplatin + Etoposide ' ' Pelareorep '
#  ' Mk-2206 ' ' Selumetinib ' ' Plicamycin ' ' Premetrexed ' ' Dasatinib '
#  ' Teprotumumab ' ' Amatuximab ' ' Apitolisib ' ' Ds-8273A '
#  ' Wt-1 Vaccine ' ' Gl-Onc1 ' ' Porfimer Sodium '
#  ' 2-(1-Hexyloxyethyl)-2-Devinyl Pyropheophorbide-A '
#  ' Topotecan + Carboplatin ' ' Rbbx-01 ' ' Altretamine ' ' Patupilone '
#  ' Oregovomab ' ' Interleukin-12 ' ' Abagovomab ' ' Hu3S193 '
#  ' Motesanib ' ' Rontalizumab ' ' Sch-58500 ' ' Aminopterin '
#  ' Chlorambucil ' ' Plevitrexed ' ' Cep-11981 ' ' Sargramostim '
#  ' Catumaxomab ' ' Olaparib ' ' Vosaroxin ' ' Interferon Gamma-1B '
#  ' Cyclophosphamide + Vincristine + Dacarbazine ' ' Bicalutamide '
#  ' Cabazitaxel ' ' Degarelix ' ' Abiraterone ' ' Buserelin '
#  ' Buserelin + Androgen Blockade ' ' Nilutamide ' ' Palbociclib '
#  ' Ontuxizumab ' ' Alisertib ' ' Ezn-2968 ' ' Enoticumab '
#  ' Evofosfamide ' ' Sulindac ' ' Raloxifene ' ' Tivozanib ' ' Gp-100 '
#  ' Mage-A3 ' ' Melphalan ' ' Vemurafenib ' ' Ondansetron '
#  ' Darbepoetin Alfa ' ' Cyclosporine ' ' Amino Acid ' ' Pv-10 '
#  ' Dabrafenib ' ' Trametinib ' ' Daunorubicin '
#  ' Polyvalent Melanoma Vaccine ' ' Atcv ' ' Pi-88 ' ' Interleukin-18 '
#  ' Interferon Alfa-2B ' ' Talimogene Laherparepvec ' ' Prs-050-Peg40 '
#  ' Treosulfan ' ' Imiquimod ' ' Diphencyprone '
#  ' Fluorouracil + Etoposide '
#  ' Plfe + Leucovorin + Fluorouracil + Oxaliplatin ' ' Plfe ' ' Didox '
#  ' Cyclophosphamide + Polysaccharide-K ' ' Doxifluridine '
#  ' Capecitabine + Oxaliplatin ' ' Gemcitabine + Oxaliplatin '
#  ' Levothyroxine ' ' Liothyronine ' ' Armour Thyroid ' ' Azathioprine '
#  ' Brivanib ' ' Tamoxifen + Megestrol '
#  ' Carboplatin + Paclitaxel + Bevacizumab ' ' Doxorubicin + Carboplatin '
#  ' Portec3 ']

# %%
cancer_treatment = pd.merge(df2, df3, on="patient_id", how="left")

# %%
cancer_treatment = cancer_treatment.drop(columns=['patient_id','has_cancer'])

# %%
cancer_treat = cancer_treatment.drop_duplicates()

# %%
cancer_treat
# Out:
#                     cancer type                     treatment           drugs
# 0      Adrenocortical carcinoma                           NaN             NaN
# 13     Adrenocortical carcinoma            Radiation Therapy     Radiation 1
# 20     Adrenocortical carcinoma   Targeted Molecular Therapy       Sunitinib
# 21     Adrenocortical carcinoma   Targeted Molecular Therapy    Ketoconazole
# 28     Adrenocortical carcinoma            Radiation Therapy     Radiation 2
# ...                         ...                           ...             ...
# 21240    Uterine Carcinosarcoma   Targeted Molecular Therapy      Paclitaxel
# 21256    Uterine Carcinosarcoma            Radiation Therapy     Radiation 3
# 21284            Uveal Melanoma                           NaN             NaN
# 21300            Uveal Melanoma                 Chemotherapy     Fotemustine
# 21331            Uveal Melanoma            Radiation Therapy     Radiation 1
#
# [1127 rows x 3 columns]

# %%
cancer_treat['treated with'] = 'treated with'
# Out:
# /var/folders/h9/pnrvl54x77d7zk45fshg0jhr0000gn/T/ipykernel_44592/3473117125.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cancer_treat['treated with'] = 'treated with'

# %%
cancer_treat
# Out:
#                     cancer type                     treatment           drugs  \
# 0      Adrenocortical carcinoma                           NaN             NaN
# 13     Adrenocortical carcinoma            Radiation Therapy     Radiation 1
# 20     Adrenocortical carcinoma   Targeted Molecular Therapy       Sunitinib
# 21     Adrenocortical carcinoma   Targeted Molecular Therapy    Ketoconazole
# 28     Adrenocortical carcinoma            Radiation Therapy     Radiation 2
# ...                         ...                           ...             ...
# 21240    Uterine Carcinosarcoma   Targeted Molecular Therapy      Paclitaxel
# 21256    Uterine Carcinosarcoma            Radiation Therapy     Radiation 3
# 21284            Uveal Melanoma                           NaN             NaN
# 21300            Uveal Melanoma                 Chemotherapy     Fotemustine
# 21331            Uveal Melanoma            Radiation Therapy     Radiation 1
#
#        treated with
# 0      treated with
# 13     treated with
# 20     treated with
# 21     treated with
# 28     treated with
# ...             ...
# 21240  treated with
# 21256  treated with
# 21284  treated with
# 21300  treated with
# 21331  treated with
#
# [1127 rows x 4 columns]

# %%
column_to_move = cancer_treat.pop('treated with')

# Insert the column at the desired location (0-indexed)
cancer_treat.insert(loc=1, column='treated with', value=column_to_move)

# %%
cancer_treat = cancer_treat.drop(columns=['drugs']).dropna(subset=['treatment']).drop_duplicates()

# %%
cancer_treat
# Out:
#                         cancer type  treated with  \
# 13         Adrenocortical carcinoma  treated with
# 20         Adrenocortical carcinoma  treated with
# 37         Adrenocortical carcinoma  treated with
# 94         Adrenocortical carcinoma  treated with
# 147    Bladder Urothelial Carcinoma  treated with
# ...                             ...           ...
# 21196        Uterine Carcinosarcoma  treated with
# 21205        Uterine Carcinosarcoma  treated with
# 21240        Uterine Carcinosarcoma  treated with
# 21300                Uveal Melanoma  treated with
# 21331                Uveal Melanoma  treated with
#
#                           treatment
# 13               Radiation Therapy
# 20      Targeted Molecular Therapy
# 37                    Chemotherapy
# 94                   Immunotherapy
# 147                  Immunotherapy
# ...                             ...
# 21196                    Ancillary
# 21205                Not Specified
# 21240   Targeted Molecular Therapy
# 21300                 Chemotherapy
# 21331            Radiation Therapy
#
# [164 rows x 3 columns]

# %%
cancer_drug = cancer_treatment.drop_duplicates()

# %%
cancer_drug['drugs used'] = 'drugs used'
# Out:
# /var/folders/h9/pnrvl54x77d7zk45fshg0jhr0000gn/T/ipykernel_44592/2486820149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cancer_drug['drugs used'] = 'drugs used'

# %%
column_to_move = cancer_drug.pop('drugs used')

# Insert the column at the desired location (0-indexed)
cancer_drug.insert(loc=1, column='drugs used', value=column_to_move)

# %%
cancer_drug
# Out:
#                     cancer type  drugs used                     treatment  \
# 0      Adrenocortical carcinoma  drugs used                           NaN
# 13     Adrenocortical carcinoma  drugs used            Radiation Therapy
# 20     Adrenocortical carcinoma  drugs used   Targeted Molecular Therapy
# 21     Adrenocortical carcinoma  drugs used   Targeted Molecular Therapy
# 28     Adrenocortical carcinoma  drugs used            Radiation Therapy
# ...                         ...         ...                           ...
# 21240    Uterine Carcinosarcoma  drugs used   Targeted Molecular Therapy
# 21256    Uterine Carcinosarcoma  drugs used            Radiation Therapy
# 21284            Uveal Melanoma  drugs used                           NaN
# 21300            Uveal Melanoma  drugs used                 Chemotherapy
# 21331            Uveal Melanoma  drugs used            Radiation Therapy
#
#                 drugs
# 0                 NaN
# 13       Radiation 1
# 20         Sunitinib
# 21      Ketoconazole
# 28       Radiation 2
# ...               ...
# 21240     Paclitaxel
# 21256    Radiation 3
# 21284             NaN
# 21300    Fotemustine
# 21331    Radiation 1
#
# [1127 rows x 4 columns]

# %%
cancer_drug = cancer_drug.drop(columns=['treatment']).dropna(subset=['drugs']).drop_duplicates()

# %%
cancer_drug
# Out:
#                     cancer type  drugs used           drugs
# 13     Adrenocortical carcinoma  drugs used    Radiation 1
# 20     Adrenocortical carcinoma  drugs used      Sunitinib
# 21     Adrenocortical carcinoma  drugs used   Ketoconazole
# 28     Adrenocortical carcinoma  drugs used    Radiation 2
# 37     Adrenocortical carcinoma  drugs used   Capecitabine
# ...                         ...         ...             ...
# 21221    Uterine Carcinosarcoma  drugs used    Doxorubicin
# 21235    Uterine Carcinosarcoma  drugs used    Gemcitabine
# 21256    Uterine Carcinosarcoma  drugs used    Radiation 3
# 21300            Uveal Melanoma  drugs used    Fotemustine
# 21331            Uveal Melanoma  drugs used    Radiation 1
#
# [907 rows x 3 columns]

# %%
df4 = pd.read_csv("tcga_gene_cancer_type.txt", sep="\t", header=0, names=['gene', 'up/downregulate', 'cancer'])

# %%
df4
# Out:
#         gene      up/downregulate                    cancer
# 0       ABAT          UPREGULATES  Adrenocortical carcinoma
# 1     ACTL6B          UPREGULATES  Adrenocortical carcinoma
# 2        AMH          UPREGULATES  Adrenocortical carcinoma
# 3     ANKHD1          UPREGULATES  Adrenocortical carcinoma
# 4     ANKRA2          UPREGULATES  Adrenocortical carcinoma
# ...      ...                  ...                       ...
# 1468  PTP4A3  UPREGULATES_ZSCORE5            Uveal Melanoma
# 1469   RIMS2  UPREGULATES_ZSCORE5            Uveal Melanoma
# 1470    SQLE  UPREGULATES_ZSCORE5            Uveal Melanoma
# 1471   TCEB1  UPREGULATES_ZSCORE5            Uveal Melanoma
# 1472   ZBED2  UPREGULATES_ZSCORE5            Uveal Melanoma
#
# [1473 rows x 3 columns]

# %%
df4['up/downregulate'] = df4['up/downregulate'].str.replace(r'UPREGULATES.*', 'UPREGULATES', regex=True)

# %%
df4['up/downregulate'] = df4['up/downregulate'].str.replace(r'DOWNREGULATES.*', 'DOWNREGULATES', regex=True)

# %%
df4
# Out:
#         gene up/downregulate                    cancer
# 0       ABAT     UPREGULATES  Adrenocortical carcinoma
# 1     ACTL6B     UPREGULATES  Adrenocortical carcinoma
# 2        AMH     UPREGULATES  Adrenocortical carcinoma
# 3     ANKHD1     UPREGULATES  Adrenocortical carcinoma
# 4     ANKRA2     UPREGULATES  Adrenocortical carcinoma
# ...      ...             ...                       ...
# 1468  PTP4A3     UPREGULATES            Uveal Melanoma
# 1469   RIMS2     UPREGULATES            Uveal Melanoma
# 1470    SQLE     UPREGULATES            Uveal Melanoma
# 1471   TCEB1     UPREGULATES            Uveal Melanoma
# 1472   ZBED2     UPREGULATES            Uveal Melanoma
#
# [1473 rows x 3 columns]

# %%
triplets=[cancer_gene, cancer_treat, cancer_drug, df4]

# %%
for triplet in triplets:
    triplet.columns = ['heads', 'relations', 'tails']

# %%
final_triplets=pd.concat(triplets, ignore_index=True)

# %%
final_triplets.head(10)
# Out:
#                       heads                             relations   tails
# 0  Adrenocortical carcinoma                      missense_variant   GFRA1
# 1  Adrenocortical carcinoma                      missense_variant    LRP6
# 2  Adrenocortical carcinoma                      missense_variant   KIF5A
# 3  Adrenocortical carcinoma                    frameshift_variant   BBS10
# 4  Adrenocortical carcinoma                           stop_gained   SUGT1
# 5  Adrenocortical carcinoma                      missense_variant  HECTD1
# 6  Adrenocortical carcinoma                    synonymous_variant    TLN2
# 7  Adrenocortical carcinoma  splice_region_variant,intron_variant   PDE8A
# 8  Adrenocortical carcinoma                      missense_variant   ANKS3
# 9  Adrenocortical carcinoma                    frameshift_variant    TP53

# %%
final_triplets.tail(10)
# Out:
#           heads    relations           tails
# 3532758  ADGRB1  UPREGULATES  Uveal Melanoma
# 3532759  DENND3  UPREGULATES  Uveal Melanoma
# 3532760   DERL1  UPREGULATES  Uveal Melanoma
# 3532761    MAL2  UPREGULATES  Uveal Melanoma
# 3532762   MMP16  UPREGULATES  Uveal Melanoma
# 3532763  PTP4A3  UPREGULATES  Uveal Melanoma
# 3532764   RIMS2  UPREGULATES  Uveal Melanoma
# 3532765    SQLE  UPREGULATES  Uveal Melanoma
# 3532766   TCEB1  UPREGULATES  Uveal Melanoma
# 3532767   ZBED2  UPREGULATES  Uveal Melanoma

# %%
final_triplets.to_csv('group40_triplets.txt', sep='\t', index=False, header=False)

# %%
cancer_gene.to_csv('cancer_to_gene_triplets.txt', sep='\t', index=False, header=False)

# %%
cancer_treat.to_csv('cancer_to_treatment_triplets.txt', sep='\t', index=False, header=False)

# %%
df4.to_csv('gene_to_up_regulate_to_cancer_triplets.txt', sep='\t', index=False, header=False)

# %%
cancer_drug.to_csv('cancer_to_drug_triplets.txt', sep='\t', index=False, header=False)
